# %%
import pandas as pd

# %%
# Load the data
df = pd.read_csv('annual_time_series_with_airports&airlines.csv')

# Perform groupby operation and calculate the yearly totals
grouped = df.groupby(['AIRLINE_ID', 'AIRCRAFT_TYPE'])['2019', '2020', '2021', '2022'].sum().reset_index()

# Drop duplicate rows for non-aggregate columns and keep the first one
non_aggregate = df[['AIRLINE_ID', 'AIRCRAFT_TYPE', 'ORIGIN_STATE_ABR', 'CODE', 'NAME', 'UNIQUE_CARRIER_NAME', 'Description']].drop_duplicates(subset=['AIRLINE_ID', 'AIRCRAFT_TYPE'])

# Merge the grouped dataframe with the non-aggregate dataframe
merged = pd.merge(non_aggregate, grouped, on=['AIRLINE_ID', 'AIRCRAFT_TYPE'])

# Reorder the columns
merged = merged[['AIRLINE_ID', 'UNIQUE_CARRIER_NAME', 'AIRCRAFT_TYPE', 'Description', '2019', '2020', '2021', '2022']]

# Save the output to a single file
merged.to_csv('annual_time_series_airlines&actypes.csv', index=False)
# Out:
# C:\Users\Juhana\AppData\Local\Temp\ipykernel_18936\2573546233.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped = df.groupby(['AIRLINE_ID', 'AIRCRAFT_TYPE'])['2019', '2020', '2021', '2022'].sum().reset_index()

# %%
merged
# Out:
#      AIRLINE_ID                              UNIQUE_CARRIER_NAME  \
# 0       19790.0                             Delta Air Lines Inc.
# 1       19790.0                             Delta Air Lines Inc.
# 2       21253.0            Multi-Aero, Inc. d/b/a Air Choice One
# 3       21599.0                                     Boutique Air
# 4       20500.0          GoJet Airlines LLC d/b/a United Express
# ..          ...                                              ...
# 180     22080.0                Breeze Aviation Group DBA  Breeze
# 181     22080.0                Breeze Aviation Group DBA  Breeze
# 182     22080.0                Breeze Aviation Group DBA  Breeze
# 183     21618.0  Southern Airways Express, dba Mokulele Airlines
# 184     21894.0                                ADVANCED AIR, LLC
#
#      AIRCRAFT_TYPE                            Description     2019     2020  \
# 0              339              Airbus Industrie A330-900     14.0      6.0
# ...
