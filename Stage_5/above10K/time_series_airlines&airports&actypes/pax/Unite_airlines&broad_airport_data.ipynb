# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 322A-B5F7
#
#  Directory of c:\Users\Juhana\Desktop\Masters_New
#
# 06/09/2023  11:33 AM    <DIR>          .
# 06/09/2023  11:33 AM    <DIR>          ..
# 06/07/2023  10:18 AM    <DIR>          2019
# 06/07/2023  10:18 AM    <DIR>          2020
# 06/07/2023  10:18 AM    <DIR>          2021
# 06/07/2023  10:18 AM    <DIR>          2022
# 06/07/2023  10:19 AM    <DIR>          2023
# 06/09/2023  11:17 AM    <DIR>          above10K
# 06/04/2023  08:07 AM             4,276 above10K_airports_ID&CODE.csv
# 06/04/2023  08:28 AM            32,335 above10K_airports_list.csv
# 06/07/2023  11:24 AM    <DIR>          above10K_list_wrangle
# 06/09/2023  07:39 AM    <DIR>          AC_family
# 06/07/2023  12:35 PM             3,740 adding_actype_description_to_time_series_deps_airline.ipynb
# 06/08/2023  07:56 AM             3,160 adding_state_abbreviates_to_above10K_airlines.ipynb
# ...

# %%
df = pd.read_csv('quarterly_time_series_with_airports&airlines.csv')

# %%
df.head()
# Out:
#    ORIGIN_AIRPORT_ID ORIGIN_STATE_ABR CODE  \
# 0              10397               GA  ATL
# 1              10397               GA  ATL
# 2              10397               GA  ATL
# 3              10397               GA  ATL
# 4              10397               GA  ATL
#
#                                                 NAME  AIRLINE_ID  \
# 0  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...     19790.0
# 1  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...     19790.0
# 2  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...     21253.0
# 3  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...     21599.0
# 4  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...     20500.0
#
#                        UNIQUE_CARRIER_NAME  AIRCRAFT_TYPE  \
# 0                     Delta Air Lines Inc.            339
# 1                     Delta Air Lines Inc.            359
# 2    Multi-Aero, Inc. d/b/a Air Choice One            415
# 3                             Boutique Air            479
# ...

# %%
df = df[['ORIGIN_AIRPORT_ID', 'AIRLINE_ID',
       'UNIQUE_CARRIER_NAME', 'AIRCRAFT_TYPE', 'Description', '2019_1Q',
       '2019_2Q', '2019_3Q', '2019_4Q', '2020_1Q', '2020_2Q', '2020_3Q',
       '2020_4Q', '2021_1Q', '2021_2Q', '2021_3Q', '2021_4Q', '2022_1Q',
       '2022_2Q', '2022_3Q', '2022_4Q']]

# %%
df
# Out:
#        ORIGIN_AIRPORT_ID  AIRLINE_ID  \
# 0                  10397     19790.0
# 1                  10397     19790.0
# 2                  10397     21253.0
# 3                  10397     21599.0
# 4                  10397     20500.0
# ...                  ...         ...
# 10922              15454     21618.0
# 10923              11197     21879.0
# 10924              10617     21894.0
# 10925              11719     20304.0
# 10926              11719     20304.0
#
#                                    UNIQUE_CARRIER_NAME  AIRCRAFT_TYPE  \
# 0                                 Delta Air Lines Inc.            339
# 1                                 Delta Air Lines Inc.            359
# 2                Multi-Aero, Inc. d/b/a Air Choice One            415
# 3                                         Boutique Air            479
# 4              GoJet Airlines LLC d/b/a United Express            530
# ...                                                ...            ...
# ...

# %%
df2 = pd.read_csv('above10K_airports_list.csv')

# %%
df2
# Out:
#      ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR  \
# 0                10135  ABE               PA
# 1                10136  ABI               TX
# 2                10140  ABQ               NM
# 3                10141  ABR               SD
# 4                10146  ABY               GA
# ..                 ...  ...              ...
# 349              15624  VPS               FL
# 350              15855  WST               RI
# 351              15919  XNA               AR
# 352              16101  YKM               WA
# 353              16869  XWA               ND
#
#                                      NAME                    LOCATION  \
# 0             Lehigh Valley International  Allentown/Bethlehem/Easton
# 1                        Abilene Regional                     Abilene
# 2       Albuquerque International Sunport                 Albuquerque
# 3                       Aberdeen Regional                    Aberdeen
# ...

# %%
merged_df = df.merge(df2, on='ORIGIN_AIRPORT_ID')

# %%
merged_df
# Out:
#        ORIGIN_AIRPORT_ID  AIRLINE_ID                      UNIQUE_CARRIER_NAME  \
# 0                  10397     19790.0                     Delta Air Lines Inc.
# 1                  10397     19790.0                     Delta Air Lines Inc.
# 2                  10397     21253.0    Multi-Aero, Inc. d/b/a Air Choice One
# 3                  10397     21599.0                             Boutique Air
# 4                  10397     20500.0  GoJet Airlines LLC d/b/a United Express
# ...                  ...         ...                                      ...
# 10922              10617     21894.0                        ADVANCED AIR, LLC
# 10923              11719     20207.0      TEM Enterprises dba  Avelo Airlines
# 10924              11719     20207.0      TEM Enterprises dba  Avelo Airlines
# 10925              11719     20304.0                    SkyWest Airlines Inc.
# 10926              11719     20304.0                    SkyWest Airlines Inc.
#
# ...

# %%
merged_df.columns
# Out:
# Index(['ORIGIN_AIRPORT_ID', 'AIRLINE_ID', 'UNIQUE_CARRIER_NAME',
#        'AIRCRAFT_TYPE', 'Description', '2019', '2020', '2021', '2022', 'CODE',
#        'ORIGIN_STATE_ABR', 'NAME', 'LOCATION', 'category', 'EAS', 'diff',
#        'pct_change', 'change_category'],
#       dtype='object')

# %%
merged_df = merged_df[['ORIGIN_AIRPORT_ID', 'CODE',
       'ORIGIN_STATE_ABR', 'NAME', 'LOCATION', 'category', 'EAS', 'diff',
       'pct_change', 'change_category', 'AIRLINE_ID', 'UNIQUE_CARRIER_NAME',
       'AIRCRAFT_TYPE', 'Description', '2019_1Q',
       '2019_2Q', '2019_3Q', '2019_4Q', '2020_1Q', '2020_2Q', '2020_3Q',
       '2020_4Q', '2021_1Q', '2021_2Q', '2021_3Q', '2021_4Q', '2022_1Q',
       '2022_2Q', '2022_3Q', '2022_4Q']]

# %%
merged_df.head()
# Out:
#    ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR  \
# 0              10397  ATL               GA
# 1              10397  ATL               GA
# 2              10397  ATL               GA
# 3              10397  ATL               GA
# 4              10397  ATL               GA
#
#                                        NAME LOCATION             category EAS  \
# 0  Hartsfield-Jackson Atlanta International  Atlanta  more than 5 million  no
# 1  Hartsfield-Jackson Atlanta International  Atlanta  more than 5 million  no
# 2  Hartsfield-Jackson Atlanta International  Atlanta  more than 5 million  no
# 3  Hartsfield-Jackson Atlanta International  Atlanta  more than 5 million  no
# 4  Hartsfield-Jackson Atlanta International  Atlanta  more than 5 million  no
#
#    diff  pct_change change_category  ...  2020_3Q 2020_4Q  2021_1Q 2021_2Q  \
# 0  loss       -20.6   at least -20%  ...      1.0     0.0      2.0     8.0
# 1  loss       -20.6   at least -20%  ...     10.0     7.0     19.0    59.0
# ...

# %%
merged_df.to_csv('quarterly_time_series_with_airports&airlines_broad.csv', index=False)
