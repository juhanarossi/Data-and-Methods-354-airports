# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 322A-B5F7
#
#  Directory of c:\Users\Juhana\Desktop\Masters_New\above10K\time_series_airlines&airports&actypes\pax
#
# 06/11/2023  04:06 PM    <DIR>          .
# 06/11/2023  04:06 PM    <DIR>          ..
# 06/11/2023  04:05 PM    <DIR>          annual_by_month_times_series
# 06/11/2023  04:06 PM               256 annual_pax_by_airline.ipynb
# 06/11/2023  02:03 PM         1,439,327 annual_time_series_pax_with_airports&airlines.csv
# 06/11/2023  04:02 PM             2,815 groupby_airline_annual.ipynb
# 06/11/2023  02:30 PM         2,008,835 quarterly_time_series_pax_with_airports&airlines.csv
# 06/09/2023  11:39 AM            63,446 Unite_airlines&broad_airport_data.ipynb
# 06/11/2023  02:05 PM            18,984 wrangling_annual_by_airport&airlines_pax.ipynb
# 06/11/2023  02:30 PM             4,126 wrangling_quarterly_by_airport&airlines_pax.ipynb
#                7 File(s)      3,537,789 bytes
# ...

# %%
df = pd.read_csv('annual_time_series_pax_with_airports&airlines.csv')

# %%
df
# Out:
#        ORIGIN_AIRPORT_ID CODE  \
# 0                  10135  ABE
# 1                  10135  ABE
# 2                  10135  ABE
# 3                  10135  ABE
# 4                  10135  ABE
# ...                  ...  ...
# 10922              15919  XNA
# 10923              15919  XNA
# 10924              15919  XNA
# 10925              16101  YKM
# 10926              16101  YKM
#
#                                                     NAME  AIRLINE_ID  \
# 0      Allentown/Bethlehem/Easton, PA: Lehigh Valley ...     19790.0
# 1      Allentown/Bethlehem/Easton, PA: Lehigh Valley ...     19790.0
# 2      Allentown/Bethlehem/Easton, PA: Lehigh Valley ...     19805.0
# 3      Allentown/Bethlehem/Easton, PA: Lehigh Valley ...     19977.0
# 4      Allentown/Bethlehem/Easton, PA: Lehigh Valley ...     19977.0
# ...                                                  ...         ...
# 10922      Fayetteville, AR: Northwest Arkansas National     19790.0
# ...

# %%
# Perform groupby operation and calculate the yearly totals
grouped = df.groupby(['AIRCRAFT_TYPE', 'Description', 'AIRLINE_ID', 'UNIQUE_CARRIER_NAME' ])['2019', '2020', '2021', '2022'].sum().reset_index()
# Out:
# C:\Users\Juhana\AppData\Local\Temp\ipykernel_24320\308824035.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped = df.groupby(['AIRCRAFT_TYPE', 'Description', 'AIRLINE_ID', 'UNIQUE_CARRIER_NAME' ])['2019', '2020', '2021', '2022'].sum().reset_index()

# %%
grouped
# Out:
#      AIRCRAFT_TYPE                         Description  AIRLINE_ID  \
# 0               30                          Cessna 180     20272.0
# 1               35  Cessna C206/207/209/210 Stationair     21636.0
# 2               36                  Cessna 172 Skyhawk     21636.0
# 3               40            De Havilland DHC2 Beaver     20272.0
# 4               40            De Havilland DHC2 Beaver     20289.0
# ..             ...                                 ...         ...
# 180            888                    Boeing 737-900ER     19790.0
# 181            888                    Boeing 737-900ER     19930.0
# 182            888                    Boeing 737-900ER     19977.0
# 183            889                 B787-900 Dreamliner     19805.0
# 184            889                 B787-900 Dreamliner     19977.0
#
#          UNIQUE_CARRIER_NAME        2019       2020        2021        2022
# 0         Kenmore Air Harbor         3.0        5.0         0.0         1.0
# ...

# %%
grouped.to_csv('annual_pax_by_actype&airline.csv', index=False)
