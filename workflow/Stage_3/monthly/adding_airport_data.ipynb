# %%
import pandas as pd

# %%
df1 = pd.read_csv('airport_codes_master_analysis.csv')

# %%
df1
# Out:
#      ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR  \
# 0                10005  05A               AK
# 1                10006  06A               AK
# 2                10011  GCW               AZ
# 3                10039  A26               AK
# 4                10042  A29               AK
# ..                 ...  ...              ...
# 808              16869  XWA               ND
# 809              16879  T4X               TX
# 810              16923  1AK               AK
# 811              16929  2AK               AK
# 812              16954  BNH               MA
#
#                                     NAME       LOCATION
# 0                   Little Squaw Airport   Little Squaw
# 1                           Kizhuyak Bay       Kizhuyak
# 2                      Grand Canyon West  Peach Springs
# 3                        Ivotuk Airstrip         Ivotuk
# 4                     Kiluda Bay Airport     Kiluda Bay
# ..                                   ...            ...
# ...

# %%
df2 = pd.read_csv('monthly/time_series_deps/time_series_deps_airport_2022.csv')

# %%
merged_df = df1.merge(df2, on='ORIGIN_AIRPORT_ID', how='inner')

# %%
merged_df
# Out:
#      ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR_x  \
# 0                10006  06A                 AK
# 1                10011  GCW                 AZ
# 2                10056  A43                 AK
# 3                10135  ABE                 PA
# 4                10136  ABI                 TX
# ..                 ...  ...                ...
# 734              16869  XWA                 ND
# 735              16879  T4X                 TX
# 736              16923  1AK                 AK
# 737              16929  2AK                 AK
# 738              16954  BNH                 MA
#
#                                     NAME                    LOCATION  \
# 0                           Kizhuyak Bay                    Kizhuyak
# 1                      Grand Canyon West               Peach Springs
# 2            Trident Basin Seaplane Base               Kodiak Island
# 3            Lehigh Valley International  Allentown/Bethlehem/Easton
# ...

# %%
merged_df.drop('ORIGIN_STATE_ABR_y', axis=1, inplace=True)
merged_df
# Out:
#      ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR_x  \
# 0                10006  06A                 AK
# 1                10011  GCW                 AZ
# 2                10056  A43                 AK
# 3                10135  ABE                 PA
# 4                10136  ABI                 TX
# ..                 ...  ...                ...
# 734              16869  XWA                 ND
# 735              16879  T4X                 TX
# 736              16923  1AK                 AK
# 737              16929  2AK                 AK
# 738              16954  BNH                 MA
#
#                                     NAME                    LOCATION    Jan  \
# 0                           Kizhuyak Bay                    Kizhuyak    NaN
# 1                      Grand Canyon West               Peach Springs    NaN
# 2            Trident Basin Seaplane Base               Kodiak Island   13.0
# 3            Lehigh Valley International  Allentown/Bethlehem/Easton  383.0
# ...

# %%
merged_df.rename(columns={'ORIGIN_STATE_ABR_x': 'ORIGIN_STATE_ABR'}, inplace=True)
merged_df
# Out:
#      ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR  \
# 0                10006  06A               AK
# 1                10011  GCW               AZ
# 2                10056  A43               AK
# 3                10135  ABE               PA
# 4                10136  ABI               TX
# ..                 ...  ...              ...
# 734              16869  XWA               ND
# 735              16879  T4X               TX
# 736              16923  1AK               AK
# 737              16929  2AK               AK
# 738              16954  BNH               MA
#
#                                     NAME                    LOCATION    Jan  \
# 0                           Kizhuyak Bay                    Kizhuyak    NaN
# 1                      Grand Canyon West               Peach Springs    NaN
# 2            Trident Basin Seaplane Base               Kodiak Island   13.0
# 3            Lehigh Valley International  Allentown/Bethlehem/Easton  383.0
# ...

# %%
merged_df.to_csv('monthly/time_series_deps/time_series_deps_airport_2022.csv', index=False)
