# %%
import pandas as pd

# %%
df = pd.read_csv('above10K_airports_list.csv')

# %%
df2 = pd.read_csv('time_series_quarterly_deps_airport.csv')

# %%
df2
# Out:
#      ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR_x  \
# 0                10005  05A                 AK
# 1                10006  06A                 AK
# 2                10011  GCW                 AZ
# 3                10039  A26                 AK
# 4                10042  A29                 AK
# ..                 ...  ...                ...
# 808              16869  XWA                 ND
# 809              16879  T4X                 TX
# 810              16923  1AK                 AK
# 811              16929  2AK                 AK
# 812              16954  BNH                 MA
#
#                                     NAME       LOCATION ORIGIN_STATE_ABR_y  \
# 0                   Little Squaw Airport   Little Squaw                 AK
# 1                           Kizhuyak Bay       Kizhuyak                 AK
# 2                      Grand Canyon West  Peach Springs                 AZ
# 3                        Ivotuk Airstrip         Ivotuk                 AK
# ...

# %%
#df2.columns

# %%
# Select the relevant columns from df2
df2_selected = df2[['ORIGIN_AIRPORT_ID', '1Q2019', '2Q2019', '3Q2019', '4Q2019', '1Q2020', '2Q2020', '3Q2020',
       '4Q2020', '1Q2021', '2Q2021', '3Q2021', '4Q2021', '1Q2022', '2Q2022',
       '3Q2022', '4Q2022']]

# Merge df with the selected columns from df2
merged_df = df.merge(df2_selected, on='ORIGIN_AIRPORT_ID', how='left')

# %%
merged_df
# Out:
#      ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR  \
# 0                10135  ABE               PA
# 1                10136  ABI               TX
# 2                10140  ABQ               NM
# 3                10141  ABR               SD
# 4                10146  ABY               GA
# ..                 ...  ...              ...
# 349              15624  VPS               FL
# 350              15855  WST               RI
# 351              15919  XNA               AR
# 352              16101  YKM               WA
# 353              16869  XWA               ND
#
#                                      NAME                    LOCATION  \
# 0             Lehigh Valley International  Allentown/Bethlehem/Easton
# 1                        Abilene Regional                     Abilene
# 2       Albuquerque International Sunport                 Albuquerque
# 3                       Aberdeen Regional                    Aberdeen
# ...

# %%
merged_df.to_csv('quarterly_deps_clusters_above10K.csv')
