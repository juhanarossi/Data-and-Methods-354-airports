# %%
import pandas as pd

# %%
df = pd.read_csv('annual_pax_clusters_above10K.csv')

# %%
df
# Out:
#      ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR  \
# 0                10135  ABE               PA
# 1                10136  ABI               TX
# 2                10140  ABQ               NM
# 3                10141  ABR               SD
# 4                10146  ABY               GA
# ..                 ...  ...              ...
# 349              15624  VPS               FL
# 350              15855  WST               RI
# 351              15919  XNA               AR
# 352              16101  YKM               WA
# 353              16869  XWA               ND
#
#                                      NAME                    LOCATION  \
# 0             Lehigh Valley International  Allentown/Bethlehem/Easton
# 1                        Abilene Regional                     Abilene
# 2       Albuquerque International Sunport                 Albuquerque
# 3                       Aberdeen Regional                    Aberdeen
# ...

# %%
df2 = df[df['category'] == '10k-100k']
df3 = df[df['category'] == '100k-1 million']

# %%
df2.describe()
# Out:
#        ORIGIN_AIRPORT_ID  pct_change    total_2019    total_2020  \
# count         127.000000  127.000000    127.000000    127.000000
# mean        12800.850394  -14.838583  36745.803150  16264.881890
# std          1745.058552   31.333683  24437.640372  11434.592016
# min         10136.000000 -100.000000  10041.000000   2816.000000
# 25%         11191.500000  -29.350000  18340.500000   8020.500000
# 50%         12891.000000  -13.500000  27225.000000  11838.000000
# 75%         14248.000000   -1.300000  51462.500000  21513.500000
# max         16869.000000  166.500000  98027.000000  53931.000000
#
#          total_2021     total_2022
# count    127.000000     127.000000
# mean   28221.661417   33234.173228
# std    20749.625392   37423.176948
# min       56.000000       0.000000
# 25%    13360.500000   14304.500000
# 50%    20386.000000   21768.000000
# 75%    37953.000000   40904.000000
# max    94733.000000  351690.000000

# %%
airports_PA = df3[df3['ORIGIN_STATE_ABR'] == 'PA']

# %%
airports_PA.describe()
# Out:
#        ORIGIN_AIRPORT_ID  pct_change     total_2019     total_2020  \
# count           6.000000     6.00000       6.000000       6.000000
# mean        12164.166667   -35.75000  321795.000000  132910.000000
# std          1767.293458    14.97154  240737.365791  103358.050541
# min         10135.000000   -52.80000  106576.000000   46272.000000
# 25%         10719.750000   -48.25000  164326.750000   64743.750000
# 50%         12237.500000   -35.55000  240093.500000   91451.000000
# 75%         13147.000000   -22.70000  400491.750000  170341.750000
# max         14711.000000   -19.70000  750978.000000  315806.000000
#
#           total_2021   total_2022
# count       6.000000       6.0000
# mean   222762.000000  255123.0000
# std    173218.116036  221183.4457
# min     68944.000000   61825.0000
# 25%    120623.500000  112898.5000
# 50%    139733.000000  156128.5000
# 75%    306453.750000  364670.5000
# max    511881.000000  623983.0000

# %%
airports_PA
# Out:
#      ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR  \
# 0                10135  ABE               PA
# 23               10434  AVP               PA
# 110              11577  ERI               PA
# 186              12898  LBE               PA
# 209              13230  MDT               PA
# 303              14711  SCE               PA
#
#                                     NAME                    LOCATION  \
# 0            Lehigh Valley International  Allentown/Bethlehem/Easton
# 23   Wilkes Barre Scranton International       Scranton/Wilkes-Barre
# 110   Erie International/Tom Ridge Field                        Erie
# 186               Arnold Palmer Regional                     Latrobe
# 209             Harrisburg International                  Harrisburg
# 303                      University Park               State College
#
#            category EAS  diff  pct_change change_category  total_2019  \
# 0    100k-1 million  no  loss       -21.7   at least -20%      437600
# ...
