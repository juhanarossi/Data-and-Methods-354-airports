# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 322A-B5F7
#
#  Directory of c:\Users\Juhana\Desktop\Masters_New\above10K\time_series_airlines&airports&actypes\deps\annual_combos
#
# 06/15/2023  12:50 PM    <DIR>          .
# 06/15/2023  12:50 PM    <DIR>          ..
# 06/08/2023  10:21 AM            15,800 annual_time_series_actypes&airlines.csv
# 06/09/2023  08:04 AM            18,439 annual_time_series_actypes&airlines_with_ACfamily.csv
# 06/08/2023  11:50 AM            13,953 annual_time_series_airlines&actypes.csv
# 06/09/2023  08:00 AM               859 annual_time_series_by_ACfamily@above10K.csv
# 06/08/2023  10:50 AM           482,967 annual_time_series_by_actypes@airports.csv
# 06/08/2023  10:44 AM           367,133 annual_time_series_by_airlines@airports.csv
# 05/29/2023  08:52 AM            44,752 EXCL_airports_list.csv
# 06/08/2023  10:51 AM            10,287 groupby_annual_actypes&airlines.ipynb
# ...

# %%
df1 = pd.read_csv('annual_time_series_by_airlines@airports.csv')

# %%
df2 = pd.read_csv('EXCL_airports_list.csv')

# %%
df2.head()
# Out:
#    ORIGIN_AIRPORT_ID CODE ORIGIN_STATE_ABR                               NAME  \
# 0              10011  GCW               AZ                  Grand Canyon West
# 1              10135  ABE               PA        Lehigh Valley International
# 2              10136  ABI               TX                   Abilene Regional
# 3              10140  ABQ               NM  Albuquerque International Sunport
# 4              10141  ABR               SD                  Aberdeen Regional
#
#                      LOCATION        category  EAS  diff  pct_change  \
# 0               Peach Springs   less than 10k   no  gain         NaN
# 1  Allentown/Bethlehem/Easton  100k-1 million   no  loss       -21.7
# 2                     Abilene        10k-100k   no  loss       -16.8
# 3                 Albuquerque     1-5 million   no  loss       -19.7
# 4                    Aberdeen        10k-100k  yes  loss        -5.4
#
#   change_category
# 0           other
# 1   at least -20%
# 2   at least -10%
# ...

# %%
df1.head()
# Out:
#    ORIGIN_AIRPORT_ID ORIGIN_STATE_ABR CODE  \
# 0              10397               GA  ATL
# 1              10397               GA  ATL
# 2              10397               GA  ATL
# 3              10397               GA  ATL
# 4              10397               GA  ATL
#
#                                                 NAME  AIRLINE_ID  \
# 0  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       19790
# 1  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       21253
# 2  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       21599
# 3  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       20500
# 4  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       19393
#
#                        UNIQUE_CARRIER_NAME    2019    2020    2021    2022
# 0                     Delta Air Lines Inc.  244020  141572  181917  207267
# 1    Multi-Aero, Inc. d/b/a Air Choice One     259     307     118       0
# 2                             Boutique Air    1351    1188     868     302
# ...

# %%
df1
