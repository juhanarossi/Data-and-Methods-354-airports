# %%
import pandas as pd

# %%
df.columns
# Out:
# Index(['ORIGIN_AIRPORT_ID', 'ORIGIN_STATE_ABR', 'CODE', 'NAME', 'AIRLINE_ID',
#        'UNIQUE_CARRIER_NAME', 'AIRCRAFT_TYPE', 'Description', '2019', '2020',
#        '2021', '2022'],
#       dtype='object')

# %%
# Load the data
df = pd.read_csv('annual_time_series_with_airports&airlines.csv')

# Perform groupby operation and calculate the yearly totals
grouped = df.groupby(['ORIGIN_AIRPORT_ID', 'AIRLINE_ID'])['2019', '2020', '2021', '2022'].sum().reset_index()

# Drop duplicate rows for non-aggregate columns and keep the first one
non_aggregate = df[['ORIGIN_AIRPORT_ID', 'AIRLINE_ID', 'ORIGIN_STATE_ABR', 'CODE', 'NAME', 'UNIQUE_CARRIER_NAME']].drop_duplicates(subset=['ORIGIN_AIRPORT_ID', 'AIRLINE_ID'])

# Merge the grouped dataframe with the non-aggregate dataframe
merged = pd.merge(non_aggregate, grouped, on=['ORIGIN_AIRPORT_ID', 'AIRLINE_ID'])

# Reorder the columns
merged = merged[['ORIGIN_AIRPORT_ID', 'ORIGIN_STATE_ABR', 'CODE', 'NAME', 'AIRLINE_ID', 'UNIQUE_CARRIER_NAME', '2019', '2020', '2021', '2022']]

# Save the output to a single file
merged.to_csv('time_series_by_airlines@airports.csv', index=False)
# Out:
# C:\Users\Juhana\AppData\Local\Temp\ipykernel_17516\2610845692.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped = df.groupby(['ORIGIN_AIRPORT_ID', 'AIRLINE_ID'])['2019', '2020', '2021', '2022'].sum().reset_index()

# %%
# Out:
#       ORIGIN_AIRPORT_ID ORIGIN_STATE_ABR CODE  \
# 0                 10397               GA  ATL
# 1                 10397               GA  ATL
# 2                 10397               GA  ATL
# 3                 10397               GA  ATL
# 4                 10397               GA  ATL
# ...                 ...              ...  ...
# 3605              13121               WV  LWB
# 3606              10559               WA  BFI
# 3607              14306               MA  PVC
# 3608              15454               IL  UIN
# 3609              11719               CO  FNL
#
#                                                    NAME  AIRLINE_ID  \
# 0     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...     19790.0
# 1     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...     21253.0
# 2     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...     21599.0
# 3     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...     20500.0
# ...
